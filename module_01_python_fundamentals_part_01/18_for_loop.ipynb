# %% [markdown]
# # **Loops: 1. FOR Loop in Python**
# - Print output multiple times

# %%
# example of a for loop in Python
for i in range(5):
    print("Python is fun!")
# Out:
# Python is fun!
# Python is fun!
# Python is fun!
# Python is fun!
# Python is fun!

# %%
# looping throug string
for char in "Usman":
    print(char)
# Out:
# U
# s
# m
# a
# n
