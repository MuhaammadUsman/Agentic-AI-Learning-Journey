# %% [markdown]
# # **Nested Loops**
# - loop inside another loop
# - used for grids, pattern, or comparisons
# - output pairs like (0,0), (0,1), (1,0)

# %%
# example of nested loop
for i in range(3):
    print("Outer Loop")
    for j in range(2):
        print("      Inner Loop")
# Out:
# Outer Loop
#       Inner Loop
#       Inner Loop
# Outer Loop
#       Inner Loop
#       Inner Loop
# Outer Loop
#       Inner Loop
#       Inner Loop
