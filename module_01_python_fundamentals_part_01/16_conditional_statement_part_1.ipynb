# %% [markdown]
# # **Conditional Statement-Part-01**
# ### Key Words:
# - 1. if: if it is raining take umberella
# - 2. else: else dinit take umberella

# %%
# weather updates
temp = 30
if temp > 25:
    print("It is hot weather.")
else:
    print("It is not hot weather.")
# Out:
# It is hot weather.

# %%
# input from user
tem = int(input("Enter the Temperature:")) # convert to integer
print(type(tem)) # check the data type of tem

if tem > 25:
    print("Its hot outside.")
else:
    print("Its not hot outside.")
# Out:
# <class 'int'>
# Its hot outside.
