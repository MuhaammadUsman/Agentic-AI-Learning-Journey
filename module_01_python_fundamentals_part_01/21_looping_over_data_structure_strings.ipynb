# %% [markdown]
# # **Looping Over Data Structures-Strings**

# %%
# example
count = 0
for char in "Banana":
    if char == "a":
        count +=1
print(count)
# Out:
# 3

# %%
# example
p = "PYTHON"
rev = ""
for char in p:
    rev = char + rev
print(rev)
# Out:
# NOHTYP
