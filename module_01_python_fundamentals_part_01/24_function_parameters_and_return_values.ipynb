# %% [markdown]
# # **Function Parameters & Return Values**

# %%
# add values
def add(a, b):
    return a + b
result = add(10, 5)
print(result)
# Out:
# 15

# %%
# square a number
def square(num):
    return num * num
result = square(5)
print(result)
# Out:
# 25
