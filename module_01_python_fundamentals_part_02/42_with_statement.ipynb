# %% [markdown]
# # **Using content Managers - with statement**
# - A context manager is a safer and cleaner way to work with resources like:
# - files
# - databases
# - network connections

# %%
with open("file.txt", "r") as file:
    data = file.read()
    print(data)
# File is automatically closed after the with block
# Out:
# This is a new line.
# This another line
# This another line
