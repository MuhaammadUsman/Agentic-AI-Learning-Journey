# %% [markdown]
# # **Introduction to Exceptions**

# %% [markdown]
# ### **Importance of Exception Handling:**
# - due to an error, python will stop the program and display an error message instead, we should handle the error and allow the program to continuenrunning.
# - program should not crash due to error
# ### **Common Errors:**
# - 1. ZeroDivisionError
# - 2. FileNotFoundError
# - 3. ValueError
