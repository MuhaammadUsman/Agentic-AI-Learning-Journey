# %% [markdown]
# # **Introduction to Seaborn Visualization**

# %% [markdown]
# # 1. Import Libraries & Dataset

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset - healthcare dataset
df = pd.read_csv("../datasets/healthcare.csv")

# %%
# sample size and display 1st five rows
df = df.sample(500)
df.head()
# Out:
#       patient_id           visit_date age_group  gender region  \
# 2521        2522  2022-04-16 01:00:00     18-30    Male  South
# 3890        3891  2022-06-12 02:00:00     46-60    Male   East
# 2576        2577  2022-04-18 08:00:00       60+    Male  North
# 2895        2896  2022-05-01 15:00:00       60+    Male  North
# 4188        4189  2022-06-24 12:00:00     46-60  Female  North
#
#             department treatment_type visit_type  length_of_stay_days  \
# 2521  General Medicine    Observation    Routine                  3.9
# 3890  General Medicine        Therapy    Routine                  7.2
# 2576        Pediatrics        Surgery    Routine                  3.1
# 2895        Cardiology        Surgery    Routine                  3.9
# 4188  General Medicine     Medication    Routine                  2.8
#
#       treatment_cost  recovery_score  readmission_risk
# 2521         68195.0            48.0              0.47
# 3890         70064.0            91.0              0.17
# 2576         57917.0            56.0              0.12
# 2895         54865.0            94.0              0.19
# 4188         67606.0            78.0              0.28

# %% [markdown]
# # 2. Scatter Plot (Axes Level)

# %%
# scatter plot
sns.scatterplot(data = df, x = "treatment_cost", y = "recovery_score", hue = "visit_type")
plt.title("Treatment Cost vs Recovery Score")
plt.show()

# %% [markdown]
# # 3.  Relational Plot - Figure Level

# %%
# set theme
sns.set_theme(style = "darkgrid")
sns.relplot(data = df, x = "treatment_cost", y = "recovery_score", hue = "visit_type", col = "gender")
plt.show()
