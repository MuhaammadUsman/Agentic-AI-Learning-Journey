# %% [markdown]
# # **Heatmap & Correlation Visualization**

# %% [markdown]
# # 1. Import libraries & Dataset

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load dataset - healthcare
df = pd.read_csv("../datasets/healthcare.csv")

# %% [markdown]
# # 2. Select Numeric Cols

# %%
# select numeric cols.
numeric_cols = df[["length_of_stay_days", "treatment_cost", "recovery_score", "readmission_risk"]]

# %% [markdown]
# # 3. Correlation Matrix

# %%
# correlation matrix of numeric cols
corr_matrix = numeric_cols.corr()
corr_matrix
# Out:
#                      length_of_stay_days  treatment_cost  recovery_score  \
# length_of_stay_days             1.000000       -0.022281        0.012183
# treatment_cost                 -0.022281        1.000000       -0.014562
# recovery_score                  0.012183       -0.014562        1.000000
# readmission_risk               -0.000935        0.017822        0.002052
#
#                      readmission_risk
# length_of_stay_days         -0.000935
# treatment_cost               0.017822
# recovery_score               0.002052
# readmission_risk             1.000000

# %% [markdown]
# # 4. Heatmap - Basic Visualization

# %%
# heatmap
sns.heatmap(corr_matrix, annot = True, cmap = "coolwarm")
plt.title("Correlation Heatmap")
plt.show()
